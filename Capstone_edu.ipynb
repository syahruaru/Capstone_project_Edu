# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns

# %%
akreditasi_negri = pd.read_csv('C:/Users/syahru/Desktop/Tetris Program/Capstone_project_Edu/Sekolah Negeri.csv')

# %%
add_NegriSiswa = pd.read_csv('NegriSiswa_data-jumlah-siswa-sekolah-menengah-pertama-smp-negeri-berdasarkan-jenis-kelamin-di-kota-bekasi-s.csv')
add_NegrGuruSertif = pd.read_csv('NegriGuruSertif_data-jumlah-guru-sekolah-menengah-pertama-smp-negeri-berdasarkan-sertifikasi-di-kota-bekasi-shee.csv')
add_NegriGuruKual = pd.read_csv('NegriGuruKual_data-jumlah-guru-smp-negeri-berdasarkan-kualifikasi-pendidikan-sheet1.csv')
add_NegriGuru = pd.read_csv('NegriGuru_rasio-siswa-dengan-tenaga-pendidik-smp-negeri-sheet1.csv')

# %%
(pd.concat([akreditasi_negri,add_NegriSiswa, add_NegrGuruSertif,add_NegriGuruKual,add_NegriGuru ], axis=1)
  .to_csv('Sekolah Negeri_.csv', index=False, na_rep='N/A')
)

# %%
akreditasi_negri_ = pd.read_csv('C:/Users/syahru/Desktop/Tetris Program/Capstone_project_Edu/Sekolah Negeri_.csv')

# %%
akreditasi_negri_
# Out:
#     NO    NO KEC       KECAMATAN  TERAKREDITASI (A)  TERAKREDITASI (B)  \
# 0    1  32.75.01    Bekasi Timur                  6                  0
# 1    2  32.75.02    Bekasi Barat                  3                  0
# 2    3  32.75.03    Bekasi Utara                  6                  0
# 3    4  32.75.04  Bekasi Selatan                  3                  0
# 4    5  32.75.05       Rawalumbu                  4                  0
# 5    6  32.75.06     Medansatria                  1                  2
# 6    7  32.75.07    Bantargebang                  1                  0
# 7    8  32.75.08      Pondokgede                  2                  1
# 8    9  32.75.09        Jatiasih                  6                  1
# 9   10  32.75.10    Jatisampurna                  2                  1
# 10  11  32.75.11     Mustikajaya                  5                  0
# 11  12  32.75.12    Pondokmelati                  1                  0
#
#     TERAKREDITASI (C)  \
# ...

# %%
# set the max columns to none
pd.set_option('display.max_columns', None)
akreditasi_negri_
# Out:
#     NO    NO KEC       KECAMATAN  TERAKREDITASI (A)  TERAKREDITASI (B)  \
# 0    1  32.75.01    Bekasi Timur                  6                  0
# 1    2  32.75.02    Bekasi Barat                  3                  0
# 2    3  32.75.03    Bekasi Utara                  6                  0
# 3    4  32.75.04  Bekasi Selatan                  3                  0
# 4    5  32.75.05       Rawalumbu                  4                  0
# 5    6  32.75.06     Medansatria                  1                  2
# 6    7  32.75.07    Bantargebang                  1                  0
# 7    8  32.75.08      Pondokgede                  2                  1
# 8    9  32.75.09        Jatiasih                  6                  1
# 9   10  32.75.10    Jatisampurna                  2                  1
# 10  11  32.75.11     Mustikajaya                  5                  0
# 11  12  32.75.12    Pondokmelati                  1                  0
#
#     TERAKREDITASI (C)  \
# ...

# %%
# drop function which is used in removing or deleting rows or columns from the CSV files
akreditasi_negri_.drop(['NO KEC.1','KECAMATAN.1','NO.2','NO KEC.2','KECAMATAN.2','JUMLAH SMP NEGERI.1','NO.3','NO KEC.3','KECAMATAN.3','NO.4','NO KEC.4','KECAMATAN.4','NO.5','NO KEC.5','KECAMATAN.5','JUMLAH SMP NEGERI.2','NO.6','NO KEC.6','KECAMATAN.6','JUMLAH SMP NEGERI.3','JUMLAH SISWA SMP NEGERI (LAKI-LAKI).1','JUMLAH SISWA SMP NEGERI (PEREMPUAN).1','JUMLAH GURU SMP NEGERI YANG SUDAH SERTIFIKASI.1','JUMLAH GURU SMP NEGERI YANG BELUM SERTIFIKASI.1'], inplace=True, axis=1)

# %%
akreditasi_negri_
# Out:
#     NO    NO KEC       KECAMATAN  TERAKREDITASI (A)  TERAKREDITASI (B)  \
# 0    1  32.75.01    Bekasi Timur                  6                  0
# 1    2  32.75.02    Bekasi Barat                  3                  0
# 2    3  32.75.03    Bekasi Utara                  6                  0
# 3    4  32.75.04  Bekasi Selatan                  3                  0
# 4    5  32.75.05       Rawalumbu                  4                  0
# 5    6  32.75.06     Medansatria                  1                  2
# 6    7  32.75.07    Bantargebang                  1                  0
# 7    8  32.75.08      Pondokgede                  2                  1
# 8    9  32.75.09        Jatiasih                  6                  1
# 9   10  32.75.10    Jatisampurna                  2                  1
# 10  11  32.75.11     Mustikajaya                  5                  0
# 11  12  32.75.12    Pondokmelati                  1                  0
#
#     TERAKREDITASI (C)  \
# ...

# %%
akreditasi_negri_.drop('NO.1', inplace=True, axis=1)

# %%
akreditasi_negri_
# Out:
#     NO    NO KEC       KECAMATAN  TERAKREDITASI (A)  TERAKREDITASI (B)  \
# 0    1  32.75.01    Bekasi Timur                  6                  0
# 1    2  32.75.02    Bekasi Barat                  3                  0
# 2    3  32.75.03    Bekasi Utara                  6                  0
# 3    4  32.75.04  Bekasi Selatan                  3                  0
# 4    5  32.75.05       Rawalumbu                  4                  0
# 5    6  32.75.06     Medansatria                  1                  2
# 6    7  32.75.07    Bantargebang                  1                  0
# 7    8  32.75.08      Pondokgede                  2                  1
# 8    9  32.75.09        Jatiasih                  6                  1
# 9   10  32.75.10    Jatisampurna                  2                  1
# 10  11  32.75.11     Mustikajaya                  5                  0
# 11  12  32.75.12    Pondokmelati                  1                  0
#
#     TERAKREDITASI (C)  \
# ...

# %%
akreditasi_negri_.to_csv('Sekolah Negeri_fix.csv', index=False, na_rep='N/A')

# %%
fix_negeri = pd.read_csv('C:/Users/syahru/Desktop/Tetris Program/Capstone_project_Edu/Sekolah Negeri_fix.csv')

# %%
fix_negeri
# Out:
#     NO    NO KEC       KECAMATAN  TERAKREDITASI (A)  TERAKREDITASI (B)  \
# 0    1  32.75.01    Bekasi Timur                  6                  0
# 1    2  32.75.02    Bekasi Barat                  3                  0
# 2    3  32.75.03    Bekasi Utara                  6                  0
# 3    4  32.75.04  Bekasi Selatan                  3                  0
# 4    5  32.75.05       Rawalumbu                  4                  0
# 5    6  32.75.06     Medansatria                  1                  2
# 6    7  32.75.07    Bantargebang                  1                  0
# 7    8  32.75.08      Pondokgede                  2                  1
# 8    9  32.75.09        Jatiasih                  6                  1
# 9   10  32.75.10    Jatisampurna                  2                  1
# 10  11  32.75.11     Mustikajaya                  5                  0
# 11  12  32.75.12    Pondokmelati                  1                  0
#
#     TERAKREDITASI (C)  \
# ...

# %%
fix_negeri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 23 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   NO                                                         12 non-null     int64
#  1   NO KEC                                                     12 non-null     object
#  2   KECAMATAN                                                  12 non-null     object
#  3   TERAKREDITASI (A)                                          12 non-null     int64
#  4   TERAKREDITASI (B)                                          12 non-null     int64
#  5   TERAKREDITASI (C)                                          12 non-null     int64
#  6   SEKOLAH MENENGAH PERTAMA (SMP) NEGERI BELUM TERAKREDITASI  12 non-null     int64
#  7   JUMLAH TOTAL SEKOLAH MENENGAH PERTAMA (SMP)                12 non-null     int64
# ...

# %%
fix_negeri['JUMLAH TOTAL SISWA'] = fix_negeri['JUMLAH SISWA SMP NEGERI (LAKI-LAKI)'] + fix_negeri['JUMLAH SISWA SMP NEGERI (PEREMPUAN)']

# %%
fix_negeri.to_csv('fix_negeri_.csv', index=False)

# %%
fix_negeri = pd.read_csv('fix_negeri_.csv')

# %%
fix_negeri
# Out:
#     NO    NO KEC       KECAMATAN  TERAKREDITASI (A)  TERAKREDITASI (B)  \
# 0    1  32.75.01    Bekasi Timur                  6                  0
# 1    2  32.75.02    Bekasi Barat                  3                  0
# 2    3  32.75.03    Bekasi Utara                  6                  0
# 3    4  32.75.04  Bekasi Selatan                  3                  0
# 4    5  32.75.05       Rawalumbu                  4                  0
# 5    6  32.75.06     Medansatria                  1                  2
# 6    7  32.75.07    Bantargebang                  1                  0
# 7    8  32.75.08      Pondokgede                  2                  1
# 8    9  32.75.09        Jatiasih                  6                  1
# 9   10  32.75.10    Jatisampurna                  2                  1
# 10  11  32.75.11     Mustikajaya                  5                  0
# 11  12  32.75.12    Pondokmelati                  1                  0
#
#     TERAKREDITASI (C)  \
# ...

# %%
fix_negeri = fix_negeri.rename(columns={'RASIO': 'RASIO (perbandingan Jumlah Murid dengan Jumlah Guru)'})
fix_negeri.to_csv('fix_negeri_.csv', index=False)

# %%
fix_negeri = pd.read_csv('fix_negeri_.csv')
fix_negeri
# Out:
#     NO    NO KEC       KECAMATAN  TERAKREDITASI (A)  TERAKREDITASI (B)  \
# 0    1  32.75.01    Bekasi Timur                  6                  0
# 1    2  32.75.02    Bekasi Barat                  3                  0
# 2    3  32.75.03    Bekasi Utara                  6                  0
# 3    4  32.75.04  Bekasi Selatan                  3                  0
# 4    5  32.75.05       Rawalumbu                  4                  0
# 5    6  32.75.06     Medansatria                  1                  2
# 6    7  32.75.07    Bantargebang                  1                  0
# 7    8  32.75.08      Pondokgede                  2                  1
# 8    9  32.75.09        Jatiasih                  6                  1
# 9   10  32.75.10    Jatisampurna                  2                  1
# 10  11  32.75.11     Mustikajaya                  5                  0
# 11  12  32.75.12    Pondokmelati                  1                  0
#
#     TERAKREDITASI (C)  \
# ...

# %%
fix_negeri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 23 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   NO                                                         12 non-null     int64
#  1   NO KEC                                                     12 non-null     object
#  2   KECAMATAN                                                  12 non-null     object
#  3   TERAKREDITASI (A)                                          12 non-null     int64
#  4   TERAKREDITASI (B)                                          12 non-null     int64
#  5   TERAKREDITASI (C)                                          12 non-null     int64
#  6   SEKOLAH MENENGAH PERTAMA (SMP) NEGERI BELUM TERAKREDITASI  12 non-null     int64
#  7   JUMLAH TOTAL SEKOLAH MENENGAH PERTAMA (SMP)                12 non-null     int64
# ...

# %% [markdown]
# # SWASTA

# %%
add_SwastaSiswa = pd.read_csv('SwastaSiswa_data-jumlah-siswa-sekolah-menengah-pertama-smp-swasta-berdasarkan-jenis-kelamin-di-kota-bekasi-s.csv')
add_SwastaGuruSertif = pd.read_csv('SwastaGuruSertif_data-jumlah-guru-sekolah-menengah-pertama-smp-swasta-berdasarkan-sertifikasi-di-kota-bekasi-shee.csv')
add_SwastaGuruKual = pd.read_csv('SwastaGuruKual_data-jumlah-guru-smp-swasta-berdasarkan-kualifikasi-pendidikan-sheet1.csv')
add_SwastaGuru = pd.read_csv('SwastaGuru_rasio-siswa-dengan-tenaga-pendidik-smp-swasta-sheet1.csv')
add_SwastaAkr = pd.read_csv('SwastaAkr_data-jumlah-sekolah-menengah-pertama-smp-swasta-berdasarkan-akreditasi-di-kota-bekasi-sheet1.csv')
add_SwastaKelas = pd.read_csv('SwastaKelas_data-jumlah-ruang-kelas-sekolah-menengah-pertama-smp-swasta-di-kota-bekasi____-sheet1.csv')
add_SwastaLab = pd.read_csv('SwastaLab_data-jumlah-fasilitas-laboratorium-sekolah-menengah-pertama-smp-swasta-di-kota-bekasi-sheet1.csv')

# %%
(pd.concat([add_SwastaAkr, add_SwastaKelas, add_SwastaLab, add_SwastaSiswa, add_SwastaGuruSertif, add_SwastaGuruKual, add_SwastaGuru], axis=1)
  .to_csv('Sekolah Swasta_.csv', index=False, na_rep='N/A')
)

# %%
akreditasi_Swasta_ = pd.read_csv('C:/Users/syahru/Desktop/Tetris Program/Capstone_project_Edu/Sekolah Swasta_.csv')
akreditasi_Swasta_
# Out:
#     NO    NO KEC       KECAMATAN  TERAKREDITASI (A)  TERAKREDITASI (B)  \
# 0    1  32.75.01    Bekasi Timur                 15                  4
# 1    2  32.75.02    Bekasi Barat                  9                  2
# 2    3  32.75.03    Bekasi Utara                 25                  6
# 3    4  32.75.04  Bekasi Selatan                  9                  4
# 4    5  32.75.05       Rawalumbu                 20                  2
# 5    6  32.75.06     Medansatria                 18                  5
# 6    7  32.75.07    Bantargebang                  6                  1
# 7    8  32.75.08      Pondokgede                 10                  2
# 8    9  32.75.09        Jatiasih                 14                  9
# 9   10  32.75.10    Jatisampurna                 10                  1
# 10  11  32.75.11     Mustikajaya                 14                  4
# 11  12  32.75.12    Pondokmelati                  9                  5
#
#     TERAKREDITASI (C)  \
# ...

# %%
akreditasi_Swasta_.drop(['NO.1','NO KEC.1','KECAMATAN.1','NO.2','NO KEC.2','KECAMATAN.2','JUMLAH SMP SWASTA.1','NO.3','NO KEC.3','KECAMATAN.3','NO.4','NO KEC.4','KECAMATAN.4','NO.5','NO KEC.5','KECAMATAN.5','JUMLAH SMP SWASTA.2','NO.6','NO KEC.6','KECAMATAN.6','JUMLAH SMP SWASTA.3','JUMLAH SISWA SMP SWASTA (LAKI-LAKI).1','JUMLAH SISWA SMP SWASTA (PEREMPUAN).1','JUMLAH GURU SMP SWASTA YANG SUDAH SERTIFIKASI.1','JUMLAH GURU SMP SWASTA YANG BELUM SERTIFIKASI.1'], inplace=True, axis=1)

# %%
akreditasi_Swasta_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 23 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   NO                                                         12 non-null     int64
#  1   NO KEC                                                     12 non-null     object
#  2   KECAMATAN                                                  12 non-null     object
#  3   TERAKREDITASI (A)                                          12 non-null     int64
#  4   TERAKREDITASI (B)                                          12 non-null     int64
#  5   TERAKREDITASI (C)                                          12 non-null     int64
#  6   SEKOLAH MENENGAH PERTAMA (SMP) SWASTA BELUM TERAKREDITASI  12 non-null     int64
#  7   JUMLAH TOTAL SEKOLAH MENENGAH PERTAMA (SMP)                12 non-null     int64
# ...

# %%
akreditasi_Swasta_
# Out:
#     NO    NO KEC       KECAMATAN  TERAKREDITASI (A)  TERAKREDITASI (B)  \
# 0    1  32.75.01    Bekasi Timur                 15                  4
# 1    2  32.75.02    Bekasi Barat                  9                  2
# 2    3  32.75.03    Bekasi Utara                 25                  6
# 3    4  32.75.04  Bekasi Selatan                  9                  4
# 4    5  32.75.05       Rawalumbu                 20                  2
# 5    6  32.75.06     Medansatria                 18                  5
# 6    7  32.75.07    Bantargebang                  6                  1
# 7    8  32.75.08      Pondokgede                 10                  2
# 8    9  32.75.09        Jatiasih                 14                  9
# 9   10  32.75.10    Jatisampurna                 10                  1
# 10  11  32.75.11     Mustikajaya                 14                  4
# 11  12  32.75.12    Pondokmelati                  9                  5
#
#     TERAKREDITASI (C)  \
# ...

# %%
akreditasi_Swasta_.to_csv('Sekolah Swasta_fix.csv', index=False, na_rep='N/A')

# %%
fix_swasta = pd.read_csv('C:/Users/syahru/Desktop/Tetris Program/Capstone_project_Edu/Sekolah Swasta_fix.csv')

# %%
fix_swasta
# Out:
#     NO    NO KEC       KECAMATAN  TERAKREDITASI (A)  TERAKREDITASI (B)  \
# 0    1  32.75.01    Bekasi Timur                 15                  4
# 1    2  32.75.02    Bekasi Barat                  9                  2
# 2    3  32.75.03    Bekasi Utara                 25                  6
# 3    4  32.75.04  Bekasi Selatan                  9                  4
# 4    5  32.75.05       Rawalumbu                 20                  2
# 5    6  32.75.06     Medansatria                 18                  5
# 6    7  32.75.07    Bantargebang                  6                  1
# 7    8  32.75.08      Pondokgede                 10                  2
# 8    9  32.75.09        Jatiasih                 14                  9
# 9   10  32.75.10    Jatisampurna                 10                  1
# 10  11  32.75.11     Mustikajaya                 14                  4
# 11  12  32.75.12    Pondokmelati                  9                  5
#
#     TERAKREDITASI (C)  \
# ...

# %%
fix_swasta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 23 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   NO                                                         12 non-null     int64
#  1   NO KEC                                                     12 non-null     object
#  2   KECAMATAN                                                  12 non-null     object
#  3   TERAKREDITASI (A)                                          12 non-null     int64
#  4   TERAKREDITASI (B)                                          12 non-null     int64
#  5   TERAKREDITASI (C)                                          12 non-null     int64
#  6   SEKOLAH MENENGAH PERTAMA (SMP) SWASTA BELUM TERAKREDITASI  12 non-null     int64
#  7   JUMLAH TOTAL SEKOLAH MENENGAH PERTAMA (SMP)                12 non-null     int64
# ...

# %%
fix_swasta['JUMLAH TOTAL SISWA'] = fix_swasta['JUMLAH SISWA SMP SWASTA (LAKI-LAKI)'] + fix_swasta['JUMLAH SISWA SMP SWASTA (PEREMPUAN)']

# %%
fix_swasta
# Out:
#     NO    NO KEC       KECAMATAN  TERAKREDITASI (A)  TERAKREDITASI (B)  \
# 0    1  32.75.01    Bekasi Timur                 15                  4
# 1    2  32.75.02    Bekasi Barat                  9                  2
# 2    3  32.75.03    Bekasi Utara                 25                  6
# 3    4  32.75.04  Bekasi Selatan                  9                  4
# 4    5  32.75.05       Rawalumbu                 20                  2
# 5    6  32.75.06     Medansatria                 18                  5
# 6    7  32.75.07    Bantargebang                  6                  1
# 7    8  32.75.08      Pondokgede                 10                  2
# 8    9  32.75.09        Jatiasih                 14                  9
# 9   10  32.75.10    Jatisampurna                 10                  1
# 10  11  32.75.11     Mustikajaya                 14                  4
# 11  12  32.75.12    Pondokmelati                  9                  5
#
#     TERAKREDITASI (C)  \
# ...

# %%
fix_swasta.to_csv('fix_swasta_.csv', index=False)

# %%
fix_swasta = pd.read_csv('fix_swasta_.csv')

# %%
fix_swasta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 23 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   NO                                                         12 non-null     int64
#  1   NO KEC                                                     12 non-null     object
#  2   KECAMATAN                                                  12 non-null     object
#  3   TERAKREDITASI (A)                                          12 non-null     int64
#  4   TERAKREDITASI (B)                                          12 non-null     int64
#  5   TERAKREDITASI (C)                                          12 non-null     int64
#  6   SEKOLAH MENENGAH PERTAMA (SMP) SWASTA BELUM TERAKREDITASI  12 non-null     int64
#  7   JUMLAH TOTAL SEKOLAH MENENGAH PERTAMA (SMP)                12 non-null     int64
# ...

# %%
# Mengganti nama kolom
fix_swasta = fix_swasta.rename(columns={'RASIO': 'RASIO (perbandingan Jumlah Murid dengan Jumlah Guru)'})
fix_swasta.to_csv('fix_swasta_.csv', index=False)

# %%
fix_swasta = pd.read_csv('fix_swasta_.csv')
fix_swasta
# Out:
#     NO    NO KEC       KECAMATAN  TERAKREDITASI (A)  TERAKREDITASI (B)  \
# 0    1  32.75.01    Bekasi Timur                 15                  4
# 1    2  32.75.02    Bekasi Barat                  9                  2
# 2    3  32.75.03    Bekasi Utara                 25                  6
# 3    4  32.75.04  Bekasi Selatan                  9                  4
# 4    5  32.75.05       Rawalumbu                 20                  2
# 5    6  32.75.06     Medansatria                 18                  5
# 6    7  32.75.07    Bantargebang                  6                  1
# 7    8  32.75.08      Pondokgede                 10                  2
# 8    9  32.75.09        Jatiasih                 14                  9
# 9   10  32.75.10    Jatisampurna                 10                  1
# 10  11  32.75.11     Mustikajaya                 14                  4
# 11  12  32.75.12    Pondokmelati                  9                  5
#
#     TERAKREDITASI (C)  \
# ...
